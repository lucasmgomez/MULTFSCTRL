# %%
import pandas as pd

sc_df = pd.read_csv("/mnt/store1/lucas/checkpoints/fixed/tf_medium_full_3000eps_ubt_semifixed/results/ctrl_pred_betas/LH_RH/nps5to50/MASTER_selected_conditions.csv")
print(list(sc_df.columns))
# Out:
# ['Task', 'ROI', 'Trial_Index', 'Condition', 'Threshold_Used']

# %% [markdown]
# OLD SETUP:
#
# 30 trials of 1back
# 52 trials of ctxdm
# 42 trials of interdms
#
# total stim: 30*5 + 52*3 + 42*4 = 504
#
# NEW SETUP:
#
# 10v:  64
# 8BL:  64
# 8C: 60
# 9-46d:  67
# p9-46v:  61
# 46:  64
#
# rnd:  48
#
# 11 trials of DMSA_CL (8BL:10, rnd:1)
# 11 trials of DMSO_LC (10v:10, rnd:1)
# 10 trials of  OnebackA_LO (46:3, 8BL:2, 9-46d:2, p9-46v:2, rnd:1)
# 10 trials of  OnebackO_LO (46:3, 8C:2, 9-46d:2, p9-46v:2, rnd:1)
# 10 trials of Twoback_LOC (10v:2, 8BL:1, 8C:2, 9-46d:2, p9-46v:2, rnd:1)
# 10 trials of Twoback_CTG (10v:2, 8BL:1, 8C:2, 9-46d:2, p9-46v:2, rnd:1)
# 7 trials of InterDMS_LOC_ABCABC (46:3, 8C:2, p9-46v:1, rnd:1)
# 7 trials of InterDMS_LOC_ABBCCA (46:3, 8C:2, 9-46d:1, rnd:1)
# 7 trials of InterDMS_CTG_ABBCCA (8BL:1, 9-46d:3, p9-46v:2, rand:1)
# 9 trials of ctxDM_OLC (10v:3, 8BL:3, 9-46d:1, p9-46v:1, rnd:1)
# 9 trials of ctxDM_LOL (10v:3, 8BL:3, 8C:2, rnd:1)
#
#
# total stim: 20*2 + 14*5 + 12*5 + 14*6 + 12*3 = 310
#
#
#
#
#
#
# 10 trials of OnebackA_LC (8C:3, 9-46d:3, p9-46v:3, rnd:1)
# 6 trials of Twoback_OBJ
